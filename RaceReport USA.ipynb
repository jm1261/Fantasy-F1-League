# %%
subprocess.run(["python", "manager.py", f'{year}'])

# %% [markdown]
# ### Manager Scores
#
# <div style="text-align: justify">
#
# It's a total domination this week by Bwoah Industries as manager James takes the top two steps again. This time it's Bwoah Moet Shell Racing taking the top spot with 241 points ahead of Bwoah OnlyFans VIP Racing with 239. A very impressive lockout at the top, and when we get to the Golf League, expect to see the Bwoah name reappearing. In third and fourth we have a double appearance from Stefanus with Haryanto and Syahrul with 236 and 214 points, respectively. Rounding out the top five is Tom, making a rare appearance in the top five this year with Mc Sled Dogs, bringing home 210 points. Down in the Golf League it's Bwoah Rolex Sipsmith Golf taking the top step, with manager James locking out both championships this week. The Golf Branch of Bwoah Industries scores an impressive -83 points ahead of nearest rival Patrick and Racing No Points with -33 points. Then it's Will with The Big One and -28 points, ahead of Stuart in fourth with Ferrari Strategists scoring -24 points. Rounding out the bottom five this week is Charlie and Lee Carvallo's F1 Challen with -16 points.
#
# Stefanus approaches the 4000 points mark at the top of the standings with Haryanto sitting comfortably on 3957 points ahead of Syahrul with 3689. A strong week for James brings Bwoah OnlyFans VIP Racing closer to the top step in third with 3663 points ahead of Patrick and Johnny UniHaas in fourth with 3646. Rounding out the top five is Stefanus and Gelael with 3562 points. Will still holds on to that top spot in the Golf League with The Big One sitting on 434 points ahead of Patrick and Racing No Points in second with 469 points. Charlie and Lee Carvallo's F1 Challen is in third with 488 points, with Joe and alpine sandbags slipping down the order in fourth with 536 points. Rounding out the bottom five is James and Bwoah Rolex Sipsmith Golf with 546 points.
#
# Our biggest winners this week were Will, Tom, and Andrew with their teams Push To Pass, Mc Sled Dogs, and I simp for Zak Brown all gaining 3 places. Our biggest loser this week was Jake and One Red Bull Car & Gasly who drop 5 places. Joining Jake at the bottom is Joe, Pete, and Pierce with their teams not competent or competitive, Peugeot Over Ford, and Ferrari Champions 2026 all dropping 3 places in the standings.
#
# </div>

# %%
team_files = [
    'LeagueTeams_Points_Bar.png',
    'LeagueTeams_Sum Points_Bar.png',
    'LeagueTeam_Sum Points.png',
    'LeagueTeams_Positions Gained_Bar.png']
directory_path = Path(f'{root}/Data/{year}/Figures/{race}')
file_paths = [
    Path(f'{directory_path}/{race}_{file}') for file in team_files]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %% [markdown]
# <div style="text-align: justify">
#
# Bwoah Industries retakes the honours of biggest budget this week, with Bwoah OnlyFans VIP Racing topping the table with $130.6 ahead of Madlen and Les Eclairs with a value of $130.0. Sam CJ is in third with Mirror, Signal, Manoeuvre worth $128.5. Also topping the cheap seats is James and Bwoah Rolex Sipsmith Golf who are now worth $44.8 at the bottom of the table. Then it's Stuart and Ferrari Strategists worth $47.4 and Patrick with their team Racing No Points worth $48.6. All values are given in millions.
#
# The team of the week this wee was Bwoah Moet Shell Racing who top the points per value table with 1.96 ppm. Then it's Haryanto with 1.87 ppm and Bwoah OnlyFans VIP Racing with 1.83 ppm. Then it's Gelael and Syahrul with 1.75 ppm, ahead o Dinoco Piston Cup Champs and Mc Sled Dogs with 1.74 ppm rounding out the top five. Worst team of the week was Bwoah Rolex Sipsmith Golf with -1.85 ppm ahead of Racing No Points with -0.68 ppm. Then it's The Big One with -0.53 ppm and Ferrari Strategists with -0.51 ppm. Rounding out the bottom five is Lee Carvallo's F1 Challen with -0.27.
#
# Points per million (ppm).
#
# </div>

# %%
team_files = [
    'LeagueTeams_Values_Bar.png',
    'LeagueTeam_Sum Values.png',
    'LeagueTeams_Points Per Value_Bar.png',
    'LeagueTeam_Average Points Per Value.png']
directory_path = Path(f'{root}/Data/{year}/Figures/{race}')
file_paths = [
    Path(f'{directory_path}/{race}_{file}') for file in team_files]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %% [markdown]
# <div style="text-align: justify">
#
# Stefanus sits at the top of the managerial scores, with their three teams coming in with 11208 points ahead of Sebastian and Josh with 9391 and 9074 points, respectively. It's Cameron in fourth place with their teams scoring a combined 8776 points, and Pete rounds out the top five with their teams scoring 8610 points. Our lowest scoring managers are the one-team heroes Chloe, Tim, Toby, and Sam CJ, scoring 2769, 2789, 3141, and 3374 respectively. In fifth place at the bottom, we have Patrick with 4115 points.
#
# Manager of the week this week is Chloe who scored an average of 233 points. Cameron is a distant second with 204 points and Matty in third with 191.33 points. Your worst manager of the week is Patrick with an average score of 89, just behind Adam with 104.67 and Stuart with 117.67 points.
#
# </div>

# %%
manager_files = [
    'LeagueManagers_Sum Points_Bar.png',
    'LeagueManagers_Sum Points.png',
    'LeagueManagers_Average Points_Bar.png',
    'LeagueManagers_Sum Average Points.png']
directory_path = Path(f'{root}/Data/{year}/Figures/{race}')
file_paths = [
    Path(f'{directory_path}/{race}_{file}') for file in manager_files]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %% [markdown]
# <div style="text-align: justify">
#
# Manager of the week this week is Stefanus with a points per value of 1.79 ppm, ahead of Chloe in second with 1.69 ppm and Josh in third with 1.64 ppm. Worst manager of the week was Adam with a points per value of 0.92 ppm, behind Pierce with 0.94 ppm and Charlie with 0.96 ppm.
#
# </div>

# %%
manager_files = [
    'LeagueManagers_Sum Values.png',
    'LeagueManagers_Average Values_Bar.png',
    'LeagueManagers_Points Per Value_Bar.png',
    'LeagueManagers_Average Points Per Value.png']
directory_path = Path(f'{root}/Data/{year}/Figures/{race}')
file_paths = [
    Path(f'{directory_path}/{race}_{file}') for file in manager_files]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %% [markdown]
# <div style="text-align: justify">
#
# I have noticed an issue with the counts so for this week, I will just leave the figures below and report on them for Austin once I can fix the issue.
#
# </div>

# %%
count_files = [
    'LeagueCounts_Driver_Bar.png',
    'LeagueCounts_Constructor_Bar.png',
    'LeagueCounts_DRS Boost_Bar.png',
    'LeagueCounts_Extra DRS_Bar.png',
    'LeagueCounts_Perks_Bar.png']
directory_path = Path(f'{root}/Data/{year}/Figures/{race}')
file_paths = [
    Path(f'{directory_path}/{race}_{file}') for file in count_files]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %%
count_files = [
    'LeagueCounts_Sum Driver.png',
    'LeagueCounts_Sum Constructor.png',
    'LeagueCounts_Sum DRS Boost.png',
    'LeagueCounts_Sum Extra DRS.png',
    'LeagueCounts_Sum Perks.png']
directory_path = Path(f'{root}/Data/{year}/Figures/{race}')
file_paths = [
    Path(f'{directory_path}/{race}_{file}') for file in count_files]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %%
count_files = [
    'LeagueCounts_Driver_Pie.png',
    'LeagueCounts_Constructor_Pie.png',
    'LeagueCounts_DRS Boost_Pie.png',
    'LeagueCounts_Perks_Pie.png']
directory_path = Path(f'{root}/Data/{year}/Figures/{race}')
file_paths = [
    Path(f'{directory_path}/{race}_{file}') for file in count_files]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %% [markdown]
# <div style="text-align: justify">
#
# For more figures, please see the Facebook group album.
#
# </div>

# %%
subprocess.run(["python", "league_prizes.py", f'{year}'])

# %% [markdown]
# <div style="text-align: justify">
#
# ## Prizes
#
# Singapore was a spot prize week with the prize "It's On Purpose" awarded to the team with the highest score, which this week was of course Bwoah Moet Shell Racing with 241 points, congratulations to manager James.
#
# Next race is Austin, and it's a sprint race!
#
# </div>

# %%
directory_path = Path(f'{root}/Data/{year}/Figures/Prizes')
file_paths = [
    Path(f'{directory_path}/{file}') for file in
    os.listdir(directory_path) if f'{race}' in file]
[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %% [markdown]
# <div style="text-align: justify">
#
# ## F1 Play
#
# Everyone scored 0 this week.
#
# That takes the scores to:
#
# Stuart - 31
#
# Josh - 40
#
# Matty - 18
#
# Tim - 36
#
# </div>

# %%
F1_play = {
    "Stuart S": [3, 5, 2, 4, 0, 2, 0, 3, 5, 4, 0, 3, 0, 0, 0, 0, 0, 0],
    "Matty J": [2, 2, 0, 0, 3, 3, 0, 2, 3, 0, 0, 1, 0, 0, 0, 2, 0, 0],
    "Josh M": [2, 3, 2, 6, 3, 3, 3, 2, 7, 0, 2, 1, 2, 2, 1, 2, 1, 0],
    "Tim W": [0, 3, 3, 0, 2, 3, 4, 4, 2, 7, 4, 3, 1, 0, 0, 0, 0, 0]}
io.save_json_dicts(
    out_path=Path(f'{root}/Data/{year}/F1_Play.json'),
    dictionary=F1_play)
#subprocess.run(["python", "F1_play.py", f'{year}'])
#points_files = [
#    'Points.png',
#    'Sum Points.png',
#    'Average Points.png']
#directory_path = Path(f'{root}/Data/{year}/Figures/F1_Play')
#file_paths = [Path(f'{directory_path}/{race}_F1Play_{file}') for file in points_files]
#[io.display_img(file_path=path, width=1200, height=720) for path in file_paths]

# %% [markdown]
# ## Next Up
#
# <div style="text-align: justify">
#
# Next up is Austin Texas at the Circuit of the Americas in quite some time, we have a long pause for everyone before we push into the final six races.
#
# </div>
